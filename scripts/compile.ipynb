# %%
import jax
import jax.numpy as jnp
import jpviz
import brax.training.agents.diffrl_shac.networks as shac_networks
from brax.training.acme import running_statistics, specs
from brax.envs.inverted_pendulum import InvertedPendulum

# %%
env = InvertedPendulum(backend="mjx")
obs_size = env.observation_size
action_size = env.action_size

# %%
network = shac_networks.make_shac_networks(
    obs_size,
    action_size,
    policy_hidden_layer_sizes=(64, 64),
    value_hidden_layer_sizes=(64, 64),
)
make_inference_fn = shac_networks.make_inference_fn(network)

prng = jax.random.PRNGKey(10)

key_policy, key_inference, key_env = jax.random.split(prng, 3)
policy_params = network.policy_network.init(key_policy)
normalizer_params = running_statistics.init_state(
    specs.Array((obs_size,), jnp.dtype('float32'))
)
inference_fn = make_inference_fn((normalizer_params, policy_params))

# %%
obs = jnp.asarray([3.0, 3.0, 3.0, 3.0])
jax.make_jaxpr(inference_fn)(obs, key_inference)
# Out:
# let silu = { lambda ; a:f32[64]. let
#     b:f32[64] = logistic a
#     c:f32[64] = mul a b
#   in (c,) } in
# { lambda d:f32[4,64] e:f32[64] f:f32[64,64] g:f32[64] h:f32[64,2] i:f32[2]; j:f32[4]
#     k:u32[2]. let
#     l:f32[64] = dot_general[dimension_numbers=(([0], [0]), ([], []))] j d
#     m:f32[64] = add l e
#     n:f32[64] = pjit[name=silu jaxpr=silu] m
#     o:f32[64] = dot_general[dimension_numbers=(([0], [0]), ([], []))] n f
#     p:f32[64] = add o g
#     q:f32[64] = pjit[name=silu jaxpr=silu] p
#     r:f32[2] = dot_general[dimension_numbers=(([0], [0]), ([], []))] q h
#     s:f32[2] = add r i
#     t:f32[1] u:f32[1] = split[axis=0 sizes=(np.int64(1), np.int64(1))] s
#     v:f32[1] = pjit[
#       name=softplus
#       jaxpr={ lambda ; w:f32[1]. let
#           x:f32[1] = custom_jvp_call[
#             call_jaxpr={ lambda ; y:f32[1] z:f32[]. let
#                 ba:f32[1] = max y z
#                 bb:f32[1] = sub y z
#                 bc:bool[1] = ne bb bb
#                 bd:f32[1] = add y z
#                 be:f32[1] = abs bb
#                 bf:f32[1] = neg be
#                 bg:f32[1] = exp bf
#                 bh:f32[1] = log1p bg
#                 bi:f32[1] = add ba bh
#                 bj:f32[1] = select_n bc bi bd
#               in (bj,) }
#             jvp_jaxpr_thunk=<function _memoize.<locals>.memoized at 0x7d74ed780940>
#             num_consts=0
#             symbolic_zeros=False
#           ] w 0.0
#         in (x,) }
#     ] u
#     bk:f32[1] = add v 0.0010000000474974513
#     bl:f32[1] = mul bk 1.0
#     bm:key<fry>[] = random_wrap[impl=fry] k
#     bn:f32[1] = pjit[
#       name=_normal
#       jaxpr={ lambda ; bo:key<fry>[]. let
#           bp:f32[1] = pjit[
#             name=_normal_real
#             jaxpr={ lambda ; bq:key<fry>[]. let
#                 br:f32[1] = pjit[
#                   name=_uniform
#                   jaxpr={ lambda ; bs:key<fry>[] bt:f32[] bu:f32[]. let
#                       bv:f32[1] = broadcast_in_dim[
#                         broadcast_dimensions=()
#                         shape=(1,)
#                         sharding=None
#                       ] bt
#                       bw:f32[1] = broadcast_in_dim[
#                         broadcast_dimensions=()
#                         shape=(1,)
#                         sharding=None
#                       ] bu
#                       bx:u32[1] = random_bits[bit_width=32 shape=(1,)] bs
#                       by:u32[1] = shift_right_logical bx 9
#                       bz:u32[1] = or by 1065353216
#                       ca:f32[1] = bitcast_convert_type[new_dtype=float32] bz
#                       cb:f32[1] = sub ca 1.0
#                       cc:f32[1] = sub bw bv
#                       cd:f32[1] = mul cb cc
#                       ce:f32[1] = add cd bv
#                       cf:f32[1] = max bv ce
#                     in (cf,) }
#                 ] bq -0.9999999403953552 1.0
#                 cg:f32[1] = erf_inv br
#                 ch:f32[1] = mul 1.4142135381698608 cg
#               in (ch,) }
#           ] bo
#         in (bp,) }
#     ] bm
#     ci:f32[1] = mul bn bl
#     cj:f32[1] = add ci t
#     ck:f32[1] = tanh cj
#   in (ck,) }

# %%
def sum_cost_utilization(cost_analysis):
    return sum(v for k, v in cost_analysis.items() if k.startswith("utilization"))

# %%
print(jax.jit(inference_fn).lower(obs, key_inference))
# Out:
# <jax._src.stages.Lowered object at 0x7d74c82e7ec0>

# %%
jax.jit(inference_fn).lower(obs, key_inference).compile().cost_analysis()
# Out:
# {'utilization6{}': 2.0,
#  'transcendentals': 133.0,
#  'utilization3{}': 4.0,
#  'bytes accessed2{}': 12.0,
#  'utilization0{}': 43.0,
#  'utilization4{}': 3.0,
#  'utilization7{}': 2.0,
#  'flops': 9579.0,
#  'bytes accessed3{}': 8.0,
#  'bytes accessed0{}': 1224.0,
#  'bytes accessed4{}': 4.0,
#  'bytes accessed': 20541.0,
#  'bytes accessedout{}': 1333.0,
#  'bytes accessed1{}': 19504.0,
#  'utilization2{}': 5.0,
#  'utilization1{}': 18.0,
#  'utilization5{}': 2.0}

# %%
jax.jit(inference_fn).lower(obs, key_inference).compile().cost_analysis()["flops"]
# Out:
# 9579.0

# %%
jitted = jax.jit(inference_fn).lower(obs, key_inference).compile().cost_analysis()
sum_cost_utilization(jitted)
# Out:
# 79.0

# %%
dot_graph = jpviz.draw(jax.jit(inference_fn))(obs, key_inference)
dot_graph.write_png("computation_graph.png")

# %%
state = env.reset(key_env)

actions = jnp.asarray([0.0])
jax.make_jaxpr(env.step)(state, actions)
# Out:
# let _take = { lambda ; a:f32[2,3] b:i32[1,0]. let
#     _:i32[1,0] = pjit[
#       name=remainder
#       jaxpr={ lambda ; c:i32[1,0] d:i32[]. let
#           e:bool[] = eq d 0
#           f:i32[] = pjit[
#             name=_where
#             jaxpr={ lambda ; g:bool[] h:i32[] i:i32[]. let
#                 j:i32[] = select_n g i h
#               in (j,) }
#           ] e 1 d
#           k:i32[1,0] = rem c f
#           l:bool[1,0] = ne k 0
#           m:bool[1,0] = lt k 0
#           n:bool[] = lt f 0
#           o:bool[1,0] = ne m n
#           p:bool[1,0] = and o l
#           q:i32[1,0] = add k f
#           r:i32[1,0] = select_n p k q
#         in (r,) }
#     ] b 2
#     s:f32[1,0,3] = broadcast_in_dim[
#       broadcast_dimensions=()
#       shape=(1, 0, 3)
#       sharding=None
#     ] 0.0
#   in (s,) } in
# let _take1 = { lambda ; t:f32[2] u:i32[1,0]. let
#     _:i32[1,0] = pjit[
#       name=remainder
#       jaxpr={ lambda ; c:i32[1,0] d:i32[]. let
#           e:bool[] = eq d 0
#           f:i32[] = pjit[
#             name=_where
#             jaxpr={ lambda ; g:bool[] h:i32[] i:i32[]. let
#                 j:i32[] = select_n g i h
#               in (j,) }
#           ] e 1 d
#           k:i32[1,0] = rem c f
#           l:bool[1,0] = ne k 0
#           m:bool[1,0] = lt k 0
#           n:bool[] = lt f 0
#           o:bool[1,0] = ne m n
#           p:bool[1,0] = and o l
#           q:i32[1,0] = add k f
#           r:i32[1,0] = select_n p k q
#         in (r,) }
#     ] u 2
#     v:f32[1,0] = broadcast_in_dim[
#       broadcast_dimensions=()
#       shape=(1, 0)
#       sharding=None
#     ] 0.0
#   in (v,) } in
# let _take2 = { lambda ; w:f32[3,3] x:i32[1]. let
#     y:i32[1] = pjit[
#       name=remainder
#       jaxpr={ lambda ; z:i32[1] ba:i32[]. let
#           bb:bool[] = eq ba 0
#           bc:i32[] = pjit[
#             name=_where
#             jaxpr={ lambda ; g:bool[] h:i32[] i:i32[]. let
#                 j:i32[] = select_n g i h
#               in (j,) }
#           ] bb 1 ba
#           bd:i32[1] = rem z bc
#           be:bool[1] = ne bd 0
#           bf:bool[1] = lt bd 0
#           bg:bool[] = lt bc 0
#           bh:bool[1] = ne bf bg
#           bi:bool[1] = and bh be
#           bj:i32[1] = add bd bc
#           bk:i32[1] = select_n bi bd bj
#         in (bk,) }
#     ] x 3
#     bl:i32[1,1] = broadcast_in_dim[
#       broadcast_dimensions=(0,)
#       shape=(1, 1)
#       sharding=None
#     ] y
#     bm:f32[1,3] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(1,), collapsed_slice_dims=(0,), start_index_map=(0,), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=False
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1, 3)
#       unique_indices=False
#     ] w bl
#   in (bm,) } in
# let _take3 = { lambda ; bn:f32[1,0,3] bo:i32[1]. let
#     bp:i32[1] = pjit[
#       name=remainder
#       jaxpr={ lambda ; z:i32[1] ba:i32[]. let
#           bb:bool[] = eq ba 0
#           bc:i32[] = pjit[
#             name=_where
#             jaxpr={ lambda ; g:bool[] h:i32[] i:i32[]. let
#                 j:i32[] = select_n g i h
#               in (j,) }
#           ] bb 1 ba
#           bd:i32[1] = rem z bc
#           be:bool[1] = ne bd 0
#           bf:bool[1] = lt bd 0
#           bg:bool[] = lt bc 0
#           bh:bool[1] = ne bf bg
#           bi:bool[1] = and bh be
#           bj:i32[1] = add bd bc
#           bk:i32[1] = select_n bi bd bj
#         in (bk,) }
#     ] bo 1
#     bq:i32[1,1] = broadcast_in_dim[
#       broadcast_dimensions=(0,)
#       shape=(1, 1)
#       sharding=None
#     ] bp
#     br:f32[1,0,3] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(1, 2), collapsed_slice_dims=(0,), start_index_map=(0,), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=False
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1, 0, 3)
#       unique_indices=False
#     ] bn bq
#   in (br,) } in
# let _take4 = { lambda ; bs:f32[1,3] bt:i32[1]. let
#     bu:i32[1] = pjit[
#       name=remainder
#       jaxpr={ lambda ; z:i32[1] ba:i32[]. let
#           bb:bool[] = eq ba 0
#           bc:i32[] = pjit[
#             name=_where
#             jaxpr={ lambda ; g:bool[] h:i32[] i:i32[]. let
#                 j:i32[] = select_n g i h
#               in (j,) }
#           ] bb 1 ba
#           bd:i32[1] = rem z bc
#           be:bool[1] = ne bd 0
#           bf:bool[1] = lt bd 0
#           bg:bool[] = lt bc 0
#           bh:bool[1] = ne bf bg
#           bi:bool[1] = and bh be
#           bj:i32[1] = add bd bc
#           bk:i32[1] = select_n bi bd bj
#         in (bk,) }
#     ] bt 1
#     bv:i32[1,1] = broadcast_in_dim[
#       broadcast_dimensions=(0,)
#       shape=(1, 1)
#       sharding=None
#     ] bu
#     bw:f32[1,3] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(1,), collapsed_slice_dims=(0,), start_index_map=(0,), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=False
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1, 3)
#       unique_indices=False
#     ] bs bv
#   in (bw,) } in
# let _take5 = { lambda ; bx:f32[1,4] by:i32[1]. let
#     bz:i32[1] = pjit[
#       name=remainder
#       jaxpr={ lambda ; z:i32[1] ba:i32[]. let
#           bb:bool[] = eq ba 0
#           bc:i32[] = pjit[
#             name=_where
#             jaxpr={ lambda ; g:bool[] h:i32[] i:i32[]. let
#                 j:i32[] = select_n g i h
#               in (j,) }
#           ] bb 1 ba
#           bd:i32[1] = rem z bc
#           be:bool[1] = ne bd 0
#           bf:bool[1] = lt bd 0
#           bg:bool[] = lt bc 0
#           bh:bool[1] = ne bf bg
#           bi:bool[1] = and bh be
#           bj:i32[1] = add bd bc
#           bk:i32[1] = select_n bi bd bj
#         in (bk,) }
#     ] by 1
#     ca:i32[1,1] = broadcast_in_dim[
#       broadcast_dimensions=(0,)
#       shape=(1, 1)
#       sharding=None
#     ] bz
#     cb:f32[1,4] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(1,), collapsed_slice_dims=(0,), start_index_map=(0,), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=False
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1, 4)
#       unique_indices=False
#     ] bx ca
#   in (cb,) } in
# let _take6 = { lambda ; cc:f32[1,3,3] cd:i32[1]. let
#     ce:i32[1] = pjit[
#       name=remainder
#       jaxpr={ lambda ; z:i32[1] ba:i32[]. let
#           bb:bool[] = eq ba 0
#           bc:i32[] = pjit[
#             name=_where
#             jaxpr={ lambda ; g:bool[] h:i32[] i:i32[]. let
#                 j:i32[] = select_n g i h
#               in (j,) }
#           ] bb 1 ba
#           bd:i32[1] = rem z bc
#           be:bool[1] = ne bd 0
#           bf:bool[1] = lt bd 0
#           bg:bool[] = lt bc 0
#           bh:bool[1] = ne bf bg
#           bi:bool[1] = and bh be
#           bj:i32[1] = add bd bc
#           bk:i32[1] = select_n bi bd bj
#         in (bk,) }
#     ] cd 1
#     cf:i32[1,1] = broadcast_in_dim[
#       broadcast_dimensions=(0,)
#       shape=(1, 1)
#       sharding=None
#     ] ce
#     cg:f32[1,3,3] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(1, 2), collapsed_slice_dims=(0,), start_index_map=(0,), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=False
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1, 3, 3)
#       unique_indices=False
#     ] cc cf
#   in (cg,) } in
# let _take7 = { lambda ; ch:f32[2,3] ci:i32[1,1]. let
#     cj:i32[1,1] = pjit[
#       name=remainder
#       jaxpr={ lambda ; ck:i32[1,1] cl:i32[]. let
#           cm:bool[] = eq cl 0
#           cn:i32[] = pjit[
#             name=_where
#             jaxpr={ lambda ; g:bool[] h:i32[] i:i32[]. let
#                 j:i32[] = select_n g i h
#               in (j,) }
#           ] cm 1 cl
#           co:i32[1,1] = rem ck cn
#           cp:bool[1,1] = ne co 0
#           cq:bool[1,1] = lt co 0
#           cr:bool[] = lt cn 0
#           cs:bool[1,1] = ne cq cr
#           ct:bool[1,1] = and cs cp
#           cu:i32[1,1] = add co cn
#           cv:i32[1,1] = select_n ct co cu
#         in (cv,) }
#     ] ci 2
#     cw:i32[1,1,1] = broadcast_in_dim[
#       broadcast_dimensions=(0, 1)
#       shape=(1, 1, 1)
#       sharding=None
#     ] cj
#     cx:f32[1,1,3] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(2,), collapsed_slice_dims=(0,), start_index_map=(0,), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=False
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1, 3)
#       unique_indices=False
#     ] ch cw
#   in (cx,) } in
# let _take8 = { lambda ; cy:f32[2] cz:i32[1,1]. let
#     da:i32[1,1] = pjit[
#       name=remainder
#       jaxpr={ lambda ; ck:i32[1,1] cl:i32[]. let
#           cm:bool[] = eq cl 0
#           cn:i32[] = pjit[
#             name=_where
#             jaxpr={ lambda ; g:bool[] h:i32[] i:i32[]. let
#                 j:i32[] = select_n g i h
#               in (j,) }
#           ] cm 1 cl
#           co:i32[1,1] = rem ck cn
#           cp:bool[1,1] = ne co 0
#           cq:bool[1,1] = lt co 0
#           cr:bool[] = lt cn 0
#           cs:bool[1,1] = ne cq cr
#           ct:bool[1,1] = and cs cp
#           cu:i32[1,1] = add co cn
#           cv:i32[1,1] = select_n ct co cu
#         in (cv,) }
#     ] cz 2
#     db:i32[1,1,1] = broadcast_in_dim[
#       broadcast_dimensions=(0, 1)
#       shape=(1, 1, 1)
#       sharding=None
#     ] da
#     dc:f32[1,1] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(), collapsed_slice_dims=(0,), start_index_map=(0,), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=False
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1,)
#       unique_indices=False
#     ] cy db
#   in (dc,) } in
# let cross = { lambda ; dd:f32[1,3] de:f32[1,3]. let
#     df:i32[1] = broadcast_in_dim[
#       broadcast_dimensions=()
#       shape=(1,)
#       sharding=None
#     ] 0
#     dg:f32[1] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0,), collapsed_slice_dims=(np.int64(1),), start_index_map=(np.int64(1),), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1, 1)
#       unique_indices=True
#     ] dd df
#     dh:i32[1] = broadcast_in_dim[
#       broadcast_dimensions=()
#       shape=(1,)
#       sharding=None
#     ] 1
#     di:f32[1] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0,), collapsed_slice_dims=(np.int64(1),), start_index_map=(np.int64(1),), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1, 1)
#       unique_indices=True
#     ] dd dh
#     dj:i32[1] = broadcast_in_dim[
#       broadcast_dimensions=()
#       shape=(1,)
#       sharding=None
#     ] 2
#     dk:f32[1] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0,), collapsed_slice_dims=(np.int64(1),), start_index_map=(np.int64(1),), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1, 1)
#       unique_indices=True
#     ] dd dj
#     dl:i32[1] = broadcast_in_dim[
#       broadcast_dimensions=()
#       shape=(1,)
#       sharding=None
#     ] 0
#     dm:f32[1] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0,), collapsed_slice_dims=(np.int64(1),), start_index_map=(np.int64(1),), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1, 1)
#       unique_indices=True
#     ] de dl
#     dn:i32[1] = broadcast_in_dim[
#       broadcast_dimensions=()
#       shape=(1,)
#       sharding=None
#     ] 1
#     do:f32[1] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0,), collapsed_slice_dims=(np.int64(1),), start_index_map=(np.int64(1),), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1, 1)
#       unique_indices=True
#     ] de dn
#     dp:i32[1] = broadcast_in_dim[
#       broadcast_dimensions=()
#       shape=(1,)
#       sharding=None
#     ] 2
#     dq:f32[1] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0,), collapsed_slice_dims=(np.int64(1),), start_index_map=(np.int64(1),), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1, 1)
#       unique_indices=True
#     ] de dp
#     dr:f32[1] = mul di dq
#     ds:f32[1] = mul dk do
#     dt:f32[1] = sub dr ds
#     du:f32[1] = mul dk dm
#     dv:f32[1] = mul dg dq
#     dw:f32[1] = sub du dv
#     dx:f32[1] = mul dg do
#     dy:f32[1] = mul di dm
#     dz:f32[1] = sub dx dy
#     ea:f32[1,1] = broadcast_in_dim[
#       broadcast_dimensions=(0,)
#       shape=(1, 1)
#       sharding=None
#     ] dt
#     eb:f32[1,1] = broadcast_in_dim[
#       broadcast_dimensions=(0,)
#       shape=(1, 1)
#       sharding=None
#     ] dw
#     ec:f32[1,1] = broadcast_in_dim[
#       broadcast_dimensions=(0,)
#       shape=(1, 1)
#       sharding=None
#     ] dz
#     ed:f32[1,3] = concatenate[dimension=1] ea eb ec
#   in (ed,) } in
# let _take9 = { lambda ; ee:f32[1,1] ef:i32[1]. let
#     eg:i32[1] = pjit[
#       name=remainder
#       jaxpr={ lambda ; z:i32[1] ba:i32[]. let
#           bb:bool[] = eq ba 0
#           bc:i32[] = pjit[
#             name=_where
#             jaxpr={ lambda ; g:bool[] h:i32[] i:i32[]. let
#                 j:i32[] = select_n g i h
#               in (j,) }
#           ] bb 1 ba
#           bd:i32[1] = rem z bc
#           be:bool[1] = ne bd 0
#           bf:bool[1] = lt bd 0
#           bg:bool[] = lt bc 0
#           bh:bool[1] = ne bf bg
#           bi:bool[1] = and bh be
#           bj:i32[1] = add bd bc
#           bk:i32[1] = select_n bi bd bj
#         in (bk,) }
#     ] ef 1
#     eh:i32[1,1] = broadcast_in_dim[
#       broadcast_dimensions=(0,)
#       shape=(1, 1)
#       sharding=None
#     ] eg
#     ei:f32[1,1] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(1,), collapsed_slice_dims=(0,), start_index_map=(0,), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=False
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1, 1)
#       unique_indices=False
#     ] ee eh
#   in (ei,) } in
# let _take10 = { lambda ; ej:f32[1,1,3] ek:i32[1]. let
#     el:i32[1] = pjit[
#       name=remainder
#       jaxpr={ lambda ; z:i32[1] ba:i32[]. let
#           bb:bool[] = eq ba 0
#           bc:i32[] = pjit[
#             name=_where
#             jaxpr={ lambda ; g:bool[] h:i32[] i:i32[]. let
#                 j:i32[] = select_n g i h
#               in (j,) }
#           ] bb 1 ba
#           bd:i32[1] = rem z bc
#           be:bool[1] = ne bd 0
#           bf:bool[1] = lt bd 0
#           bg:bool[] = lt bc 0
#           bh:bool[1] = ne bf bg
#           bi:bool[1] = and bh be
#           bj:i32[1] = add bd bc
#           bk:i32[1] = select_n bi bd bj
#         in (bk,) }
#     ] ek 1
#     em:i32[1,1] = broadcast_in_dim[
#       broadcast_dimensions=(0,)
#       shape=(1, 1)
#       sharding=None
#     ] el
#     en:f32[1,1,3] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(1, 2), collapsed_slice_dims=(0,), start_index_map=(0,), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=False
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1, 1, 3)
#       unique_indices=False
#     ] ej em
#   in (en,) } in
# let jaxpr = { lambda ; eo:i32[] ep:i32[]. let eq:i32[] = add eo ep in (eq,) } in
# let _take11 = { lambda ; er:f32[2] es:i32[2]. let
#     et:i32[2] = pjit[
#       name=remainder
#       jaxpr={ lambda ; eu:i32[2] ev:i32[]. let
#           ew:bool[] = eq ev 0
#           ex:i32[] = pjit[
#             name=_where
#             jaxpr={ lambda ; g:bool[] h:i32[] i:i32[]. let
#                 j:i32[] = select_n g i h
#               in (j,) }
#           ] ew 1 ev
#           ey:i32[2] = rem eu ex
#           ez:bool[2] = ne ey 0
#           fa:bool[2] = lt ey 0
#           fb:bool[] = lt ex 0
#           fc:bool[2] = ne fa fb
#           fd:bool[2] = and fc ez
#           fe:i32[2] = add ey ex
#           ff:i32[2] = select_n fd ey fe
#         in (ff,) }
#     ] es 2
#     fg:i32[2,1] = broadcast_in_dim[
#       broadcast_dimensions=(0,)
#       shape=(2, 1)
#       sharding=None
#     ] et
#     fh:f32[2] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(), collapsed_slice_dims=(0,), start_index_map=(0,), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=False
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1,)
#       unique_indices=False
#     ] er fg
#   in (fh,) } in
# let _take12 = { lambda ; fi:f32[2,3] fj:i32[2]. let
#     fk:i32[2] = pjit[
#       name=remainder
#       jaxpr={ lambda ; eu:i32[2] ev:i32[]. let
#           ew:bool[] = eq ev 0
#           ex:i32[] = pjit[
#             name=_where
#             jaxpr={ lambda ; g:bool[] h:i32[] i:i32[]. let
#                 j:i32[] = select_n g i h
#               in (j,) }
#           ] ew 1 ev
#           ey:i32[2] = rem eu ex
#           ez:bool[2] = ne ey 0
#           fa:bool[2] = lt ey 0
#           fb:bool[] = lt ex 0
#           fc:bool[2] = ne fa fb
#           fd:bool[2] = and fc ez
#           fe:i32[2] = add ey ex
#           ff:i32[2] = select_n fd ey fe
#         in (ff,) }
#     ] fj 2
#     fl:i32[2,1] = broadcast_in_dim[
#       broadcast_dimensions=(0,)
#       shape=(2, 1)
#       sharding=None
#     ] fk
#     fm:f32[2,3] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(1,), collapsed_slice_dims=(0,), start_index_map=(0,), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=False
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1, 3)
#       unique_indices=False
#     ] fi fl
#   in (fm,) } in
# let _take13 = { lambda ; fn:f32[3,3] fo:i32[3]. let
#     fp:i32[3] = pjit[
#       name=remainder
#       jaxpr={ lambda ; fq:i32[3] fr:i32[]. let
#           fs:bool[] = eq fr 0
#           ft:i32[] = pjit[
#             name=_where
#             jaxpr={ lambda ; g:bool[] h:i32[] i:i32[]. let
#                 j:i32[] = select_n g i h
#               in (j,) }
#           ] fs 1 fr
#           fu:i32[3] = rem fq ft
#           fv:bool[3] = ne fu 0
#           fw:bool[3] = lt fu 0
#           fx:bool[] = lt ft 0
#           fy:bool[3] = ne fw fx
#           fz:bool[3] = and fy fv
#           ga:i32[3] = add fu ft
#           gb:i32[3] = select_n fz fu ga
#         in (gb,) }
#     ] fo 3
#     gc:i32[3,1] = broadcast_in_dim[
#       broadcast_dimensions=(0,)
#       shape=(3, 1)
#       sharding=None
#     ] fp
#     gd:f32[3,3] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(1,), collapsed_slice_dims=(0,), start_index_map=(0,), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=False
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1, 3)
#       unique_indices=False
#     ] fn gc
#   in (gd,) } in
# let cross1 = { lambda ; ge:f32[3,3] gf:f32[3,3]. let
#     gg:i32[1] = broadcast_in_dim[
#       broadcast_dimensions=()
#       shape=(1,)
#       sharding=None
#     ] 0
#     gh:f32[3] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0,), collapsed_slice_dims=(np.int64(1),), start_index_map=(np.int64(1),), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(3, 1)
#       unique_indices=True
#     ] ge gg
#     gi:i32[1] = broadcast_in_dim[
#       broadcast_dimensions=()
#       shape=(1,)
#       sharding=None
#     ] 1
#     gj:f32[3] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0,), collapsed_slice_dims=(np.int64(1),), start_index_map=(np.int64(1),), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(3, 1)
#       unique_indices=True
#     ] ge gi
#     gk:i32[1] = broadcast_in_dim[
#       broadcast_dimensions=()
#       shape=(1,)
#       sharding=None
#     ] 2
#     gl:f32[3] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0,), collapsed_slice_dims=(np.int64(1),), start_index_map=(np.int64(1),), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(3, 1)
#       unique_indices=True
#     ] ge gk
#     gm:i32[1] = broadcast_in_dim[
#       broadcast_dimensions=()
#       shape=(1,)
#       sharding=None
#     ] 0
#     gn:f32[3] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0,), collapsed_slice_dims=(np.int64(1),), start_index_map=(np.int64(1),), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(3, 1)
#       unique_indices=True
#     ] gf gm
#     go:i32[1] = broadcast_in_dim[
#       broadcast_dimensions=()
#       shape=(1,)
#       sharding=None
#     ] 1
#     gp:f32[3] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0,), collapsed_slice_dims=(np.int64(1),), start_index_map=(np.int64(1),), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(3, 1)
#       unique_indices=True
#     ] gf go
#     gq:i32[1] = broadcast_in_dim[
#       broadcast_dimensions=()
#       shape=(1,)
#       sharding=None
#     ] 2
#     gr:f32[3] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0,), collapsed_slice_dims=(np.int64(1),), start_index_map=(np.int64(1),), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(3, 1)
#       unique_indices=True
#     ] gf gq
#     gs:f32[3] = mul gj gr
#     gt:f32[3] = mul gl gp
#     gu:f32[3] = sub gs gt
#     gv:f32[3] = mul gl gn
#     gw:f32[3] = mul gh gr
#     gx:f32[3] = sub gv gw
#     gy:f32[3] = mul gh gp
#     gz:f32[3] = mul gj gn
#     ha:f32[3] = sub gy gz
#     hb:f32[3,1] = broadcast_in_dim[
#       broadcast_dimensions=(0,)
#       shape=(3, 1)
#       sharding=None
#     ] gu
#     hc:f32[3,1] = broadcast_in_dim[
#       broadcast_dimensions=(0,)
#       shape=(3, 1)
#       sharding=None
#     ] gx
#     hd:f32[3,1] = broadcast_in_dim[
#       broadcast_dimensions=(0,)
#       shape=(3, 1)
#       sharding=None
#     ] ha
#     he:f32[3,3] = concatenate[dimension=1] hb hc hd
#   in (he,) } in
# let jaxpr1 = { lambda ; hf:f32[] hg:f32[]. let hh:f32[] = add hf hg in (hh,) } in
# let _take14 = { lambda ; hi:f32[2,6] hj:i32[2]. let
#     hk:i32[2] = pjit[
#       name=remainder
#       jaxpr={ lambda ; eu:i32[2] ev:i32[]. let
#           ew:bool[] = eq ev 0
#           ex:i32[] = pjit[
#             name=_where
#             jaxpr={ lambda ; g:bool[] h:i32[] i:i32[]. let
#                 j:i32[] = select_n g i h
#               in (j,) }
#           ] ew 1 ev
#           ey:i32[2] = rem eu ex
#           ez:bool[2] = ne ey 0
#           fa:bool[2] = lt ey 0
#           fb:bool[] = lt ex 0
#           fc:bool[2] = ne fa fb
#           fd:bool[2] = and fc ez
#           fe:i32[2] = add ey ex
#           ff:i32[2] = select_n fd ey fe
#         in (ff,) }
#     ] hj 2
#     hl:i32[2,1] = broadcast_in_dim[
#       broadcast_dimensions=(0,)
#       shape=(2, 1)
#       sharding=None
#     ] hk
#     hm:f32[2,6] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(1,), collapsed_slice_dims=(0,), start_index_map=(0,), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=False
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1, 6)
#       unique_indices=False
#     ] hi hl
#   in (hm,) } in
# let cross2 = { lambda ; hn:f32[2,3] ho:f32[2,3]. let
#     hp:i32[1] = broadcast_in_dim[
#       broadcast_dimensions=()
#       shape=(1,)
#       sharding=None
#     ] 0
#     hq:f32[2] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0,), collapsed_slice_dims=(np.int64(1),), start_index_map=(np.int64(1),), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(2, 1)
#       unique_indices=True
#     ] hn hp
#     hr:i32[1] = broadcast_in_dim[
#       broadcast_dimensions=()
#       shape=(1,)
#       sharding=None
#     ] 1
#     hs:f32[2] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0,), collapsed_slice_dims=(np.int64(1),), start_index_map=(np.int64(1),), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(2, 1)
#       unique_indices=True
#     ] hn hr
#     ht:i32[1] = broadcast_in_dim[
#       broadcast_dimensions=()
#       shape=(1,)
#       sharding=None
#     ] 2
#     hu:f32[2] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0,), collapsed_slice_dims=(np.int64(1),), start_index_map=(np.int64(1),), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(2, 1)
#       unique_indices=True
#     ] hn ht
#     hv:i32[1] = broadcast_in_dim[
#       broadcast_dimensions=()
#       shape=(1,)
#       sharding=None
#     ] 0
#     hw:f32[2] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0,), collapsed_slice_dims=(np.int64(1),), start_index_map=(np.int64(1),), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(2, 1)
#       unique_indices=True
#     ] ho hv
#     hx:i32[1] = broadcast_in_dim[
#       broadcast_dimensions=()
#       shape=(1,)
#       sharding=None
#     ] 1
#     hy:f32[2] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0,), collapsed_slice_dims=(np.int64(1),), start_index_map=(np.int64(1),), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(2, 1)
#       unique_indices=True
#     ] ho hx
#     hz:i32[1] = broadcast_in_dim[
#       broadcast_dimensions=()
#       shape=(1,)
#       sharding=None
#     ] 2
#     ia:f32[2] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0,), collapsed_slice_dims=(np.int64(1),), start_index_map=(np.int64(1),), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(2, 1)
#       unique_indices=True
#     ] ho hz
#     ib:f32[2] = mul hs ia
#     ic:f32[2] = mul hu hy
#     id:f32[2] = sub ib ic
#     ie:f32[2] = mul hu hw
#     if:f32[2] = mul hq ia
#     ig:f32[2] = sub ie if
#     ih:f32[2] = mul hq hy
#     ii:f32[2] = mul hs hw
#     ij:f32[2] = sub ih ii
#     ik:f32[2,1] = broadcast_in_dim[
#       broadcast_dimensions=(0,)
#       shape=(2, 1)
#       sharding=None
#     ] id
#     il:f32[2,1] = broadcast_in_dim[
#       broadcast_dimensions=(0,)
#       shape=(2, 1)
#       sharding=None
#     ] ig
#     im:f32[2,1] = broadcast_in_dim[
#       broadcast_dimensions=(0,)
#       shape=(2, 1)
#       sharding=None
#     ] ij
#     in:f32[2,3] = concatenate[dimension=1] ik il im
#   in (in,) } in
# let _diag = { lambda ; io:f32[2]. let
#     ip:f32[2] = pad[padding_config=((0, 0, 0),)] io 0.0
#     iq:i32[2,2] = iota[dimension=0 dtype=int32 shape=(2, 2) sharding=None]
#     ir:i32[2,2] = iota[dimension=1 dtype=int32 shape=(2, 2) sharding=None]
#     is:i32[2,2] = add iq 0
#     it:bool[2,2] = eq is ir
#     iu:f32[2] = broadcast_in_dim[
#       broadcast_dimensions=()
#       shape=(2,)
#       sharding=None
#     ] 0.0
#     iv:f32[2,2] = pjit[
#       name=_where
#       jaxpr={ lambda ; iw:bool[2,2] ix:f32[2] iy:f32[2]. let
#           iz:f32[2,2] = broadcast_in_dim[
#             broadcast_dimensions=(1,)
#             shape=(2, 2)
#             sharding=None
#           ] ix
#           ja:f32[2,2] = broadcast_in_dim[
#             broadcast_dimensions=(1,)
#             shape=(2, 2)
#             sharding=None
#           ] iy
#           jb:f32[2,2] = select_n iw ja iz
#         in (jb,) }
#     ] it ip iu
#   in (iv,) } in
# let _cholesky = { lambda ; jc:f32[2,2]. let
#     jd:f32[2,2] = transpose[permutation=(1, 0)] jc
#     je:f32[2,2] = cholesky jd
#     jf:i32[2,2] = iota[dimension=0 dtype=int32 shape=(2, 2) sharding=None]
#     jg:i32[2,2] = add jf 0
#     jh:i32[2,2] = iota[dimension=1 dtype=int32 shape=(2, 2) sharding=None]
#     ji:bool[2,2] = ge jg jh
#     jj:f32[2,2] = broadcast_in_dim[
#       broadcast_dimensions=()
#       shape=(2, 2)
#       sharding=None
#     ] 0.0
#     jk:f32[2,2] = select_n ji jj je
#     jl:f32[2,2] = transpose[permutation=(1, 0)] jk
#   in (jl,) } in
# let clip = { lambda ; jm:f32[2] jn:f32[] jo:f32[]. let
#     jp:f32[] = convert_element_type[new_dtype=float32 weak_type=False] jn
#     jq:f32[2] = max jp jm
#     jr:f32[] = convert_element_type[new_dtype=float32 weak_type=False] jo
#     js:f32[2] = min jr jq
#   in (js,) } in
# let _where = { lambda ; jt:bool[2] ju:f32[2] jv:f32[2]. let
#     jw:f32[2] = select_n jt jv ju
#   in (jw,) } in
# let _take15 = { lambda ; jx:f32[1,6] jy:i32[1]. let
#     jz:i32[1] = pjit[
#       name=remainder
#       jaxpr={ lambda ; z:i32[1] ba:i32[]. let
#           bb:bool[] = eq ba 0
#           bc:i32[] = pjit[
#             name=_where
#             jaxpr={ lambda ; g:bool[] h:i32[] i:i32[]. let
#                 j:i32[] = select_n g i h
#               in (j,) }
#           ] bb 1 ba
#           bd:i32[1] = rem z bc
#           be:bool[1] = ne bd 0
#           bf:bool[1] = lt bd 0
#           bg:bool[] = lt bc 0
#           bh:bool[1] = ne bf bg
#           bi:bool[1] = and bh be
#           bj:i32[1] = add bd bc
#           bk:i32[1] = select_n bi bd bj
#         in (bk,) }
#     ] jy 1
#     ka:i32[1,1] = broadcast_in_dim[
#       broadcast_dimensions=(0,)
#       shape=(1, 1)
#       sharding=None
#     ] jz
#     kb:f32[1,6] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(1,), collapsed_slice_dims=(0,), start_index_map=(0,), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=False
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1, 6)
#       unique_indices=False
#     ] jx ka
#   in (kb,) } in
# let _take16 = { lambda ; kc:f32[1,2] kd:i32[1]. let
#     ke:i32[1] = pjit[
#       name=remainder
#       jaxpr={ lambda ; z:i32[1] ba:i32[]. let
#           bb:bool[] = eq ba 0
#           bc:i32[] = pjit[
#             name=_where
#             jaxpr={ lambda ; g:bool[] h:i32[] i:i32[]. let
#                 j:i32[] = select_n g i h
#               in (j,) }
#           ] bb 1 ba
#           bd:i32[1] = rem z bc
#           be:bool[1] = ne bd 0
#           bf:bool[1] = lt bd 0
#           bg:bool[] = lt bc 0
#           bh:bool[1] = ne bf bg
#           bi:bool[1] = and bh be
#           bj:i32[1] = add bd bc
#           bk:i32[1] = select_n bi bd bj
#         in (bk,) }
#     ] kd 1
#     kf:i32[1,1] = broadcast_in_dim[
#       broadcast_dimensions=(0,)
#       shape=(1, 1)
#       sharding=None
#     ] ke
#     kg:f32[1,2] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(1,), collapsed_slice_dims=(0,), start_index_map=(0,), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=False
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1, 2)
#       unique_indices=False
#     ] kc kf
#   in (kg,) } in
# let _take17 = { lambda ; kh:f32[2,6] ki:i32[1,0]. let
#     _:i32[1,0] = pjit[
#       name=remainder
#       jaxpr={ lambda ; c:i32[1,0] d:i32[]. let
#           e:bool[] = eq d 0
#           f:i32[] = pjit[
#             name=_where
#             jaxpr={ lambda ; g:bool[] h:i32[] i:i32[]. let
#                 j:i32[] = select_n g i h
#               in (j,) }
#           ] e 1 d
#           k:i32[1,0] = rem c f
#           l:bool[1,0] = ne k 0
#           m:bool[1,0] = lt k 0
#           n:bool[] = lt f 0
#           o:bool[1,0] = ne m n
#           p:bool[1,0] = and o l
#           q:i32[1,0] = add k f
#           r:i32[1,0] = select_n p k q
#         in (r,) }
#     ] ki 2
#     kj:f32[1,0,6] = broadcast_in_dim[
#       broadcast_dimensions=()
#       shape=(1, 0, 6)
#       sharding=None
#     ] 0.0
#   in (kj,) } in
# let _take18 = { lambda ; kk:f32[2,6] kl:i32[1,1]. let
#     km:i32[1,1] = pjit[
#       name=remainder
#       jaxpr={ lambda ; ck:i32[1,1] cl:i32[]. let
#           cm:bool[] = eq cl 0
#           cn:i32[] = pjit[
#             name=_where
#             jaxpr={ lambda ; g:bool[] h:i32[] i:i32[]. let
#                 j:i32[] = select_n g i h
#               in (j,) }
#           ] cm 1 cl
#           co:i32[1,1] = rem ck cn
#           cp:bool[1,1] = ne co 0
#           cq:bool[1,1] = lt co 0
#           cr:bool[] = lt cn 0
#           cs:bool[1,1] = ne cq cr
#           ct:bool[1,1] = and cs cp
#           cu:i32[1,1] = add co cn
#           cv:i32[1,1] = select_n ct co cu
#         in (cv,) }
#     ] kl 2
#     kn:i32[1,1,1] = broadcast_in_dim[
#       broadcast_dimensions=(0, 1)
#       shape=(1, 1, 1)
#       sharding=None
#     ] km
#     ko:f32[1,1,6] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(2,), collapsed_slice_dims=(0,), start_index_map=(0,), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=False
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1, 6)
#       unique_indices=False
#     ] kk kn
#   in (ko,) } in
# let cross3 = { lambda ; kp:f32[1,3] kq:f32[1,1,3]. let
#     kr:i32[1] = broadcast_in_dim[
#       broadcast_dimensions=()
#       shape=(1,)
#       sharding=None
#     ] 0
#     ks:f32[1] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0,), collapsed_slice_dims=(np.int64(1),), start_index_map=(np.int64(1),), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1, 1)
#       unique_indices=True
#     ] kp kr
#     kt:i32[1] = broadcast_in_dim[
#       broadcast_dimensions=()
#       shape=(1,)
#       sharding=None
#     ] 1
#     ku:f32[1] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0,), collapsed_slice_dims=(np.int64(1),), start_index_map=(np.int64(1),), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1, 1)
#       unique_indices=True
#     ] kp kt
#     kv:i32[1] = broadcast_in_dim[
#       broadcast_dimensions=()
#       shape=(1,)
#       sharding=None
#     ] 2
#     kw:f32[1] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0,), collapsed_slice_dims=(np.int64(1),), start_index_map=(np.int64(1),), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1, 1)
#       unique_indices=True
#     ] kp kv
#     kx:i32[1] = broadcast_in_dim[
#       broadcast_dimensions=()
#       shape=(1,)
#       sharding=None
#     ] 0
#     ky:f32[1,1] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0, np.int64(1)), collapsed_slice_dims=(np.int64(2),), start_index_map=(np.int64(2),), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1, 1, 1)
#       unique_indices=True
#     ] kq kx
#     kz:i32[1] = broadcast_in_dim[
#       broadcast_dimensions=()
#       shape=(1,)
#       sharding=None
#     ] 1
#     la:f32[1,1] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0, np.int64(1)), collapsed_slice_dims=(np.int64(2),), start_index_map=(np.int64(2),), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1, 1, 1)
#       unique_indices=True
#     ] kq kz
#     lb:i32[1] = broadcast_in_dim[
#       broadcast_dimensions=()
#       shape=(1,)
#       sharding=None
#     ] 2
#     lc:f32[1,1] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0, np.int64(1)), collapsed_slice_dims=(np.int64(2),), start_index_map=(np.int64(2),), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1, 1, 1)
#       unique_indices=True
#     ] kq lb
#     ld:f32[1,1] = broadcast_in_dim[
#       broadcast_dimensions=(0,)
#       shape=(1, 1)
#       sharding=None
#     ] ku
#     le:f32[1,1] = mul ld lc
#     lf:f32[1,1] = broadcast_in_dim[
#       broadcast_dimensions=(0,)
#       shape=(1, 1)
#       sharding=None
#     ] kw
#     lg:f32[1,1] = mul lf la
#     lh:f32[1,1] = sub le lg
#     li:f32[1,1] = broadcast_in_dim[
#       broadcast_dimensions=(0,)
#       shape=(1, 1)
#       sharding=None
#     ] kw
#     lj:f32[1,1] = mul li ky
#     lk:f32[1,1] = broadcast_in_dim[
#       broadcast_dimensions=(0,)
#       shape=(1, 1)
#       sharding=None
#     ] ks
#     ll:f32[1,1] = mul lk lc
#     lm:f32[1,1] = sub lj ll
#     ln:f32[1,1] = broadcast_in_dim[
#       broadcast_dimensions=(0,)
#       shape=(1, 1)
#       sharding=None
#     ] ks
#     lo:f32[1,1] = mul ln la
#     lp:f32[1,1] = broadcast_in_dim[
#       broadcast_dimensions=(0,)
#       shape=(1, 1)
#       sharding=None
#     ] ku
#     lq:f32[1,1] = mul lp ky
#     lr:f32[1,1] = sub lo lq
#     ls:f32[1,1,1] = broadcast_in_dim[
#       broadcast_dimensions=(0, np.int64(1))
#       shape=(1, 1, 1)
#       sharding=None
#     ] lh
#     lt:f32[1,1,1] = broadcast_in_dim[
#       broadcast_dimensions=(0, np.int64(1))
#       shape=(1, 1, 1)
#       sharding=None
#     ] lm
#     lu:f32[1,1,1] = broadcast_in_dim[
#       broadcast_dimensions=(0, np.int64(1))
#       shape=(1, 1, 1)
#       sharding=None
#     ] lr
#     lv:f32[1,1,3] = concatenate[dimension=2] ls lt lu
#   in (lv,) } in
# let _take19 = { lambda ; lw:f32[3,6] lx:i32[3]. let
#     ly:i32[3] = pjit[
#       name=remainder
#       jaxpr={ lambda ; fq:i32[3] fr:i32[]. let
#           fs:bool[] = eq fr 0
#           ft:i32[] = pjit[
#             name=_where
#             jaxpr={ lambda ; g:bool[] h:i32[] i:i32[]. let
#                 j:i32[] = select_n g i h
#               in (j,) }
#           ] fs 1 fr
#           fu:i32[3] = rem fq ft
#           fv:bool[3] = ne fu 0
#           fw:bool[3] = lt fu 0
#           fx:bool[] = lt ft 0
#           fy:bool[3] = ne fw fx
#           fz:bool[3] = and fy fv
#           ga:i32[3] = add fu ft
#           gb:i32[3] = select_n fz fu ga
#         in (gb,) }
#     ] lx 3
#     lz:i32[3,1] = broadcast_in_dim[
#       broadcast_dimensions=(0,)
#       shape=(3, 1)
#       sharding=None
#     ] ly
#     ma:f32[3,6] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(1,), collapsed_slice_dims=(0,), start_index_map=(0,), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=False
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1, 6)
#       unique_indices=False
#     ] lw lz
#   in (ma,) } in
# let _where1 = { lambda ; mb:u8[1,1] mc:f32[1,2] md:f32[2]. let
#     me:bool[1,1] = ne mb 0
#     mf:bool[1,2] = broadcast_in_dim[
#       broadcast_dimensions=(0, 1)
#       shape=(1, 2)
#       sharding=None
#     ] me
#     mg:f32[1,2] = broadcast_in_dim[
#       broadcast_dimensions=(1,)
#       shape=(1, 2)
#       sharding=None
#     ] md
#     mh:f32[1,2] = select_n mf mg mc
#   in (mh,) } in
# let clip1 = { lambda ; mi:f32[1] mj:f32[1] mk:f32[1]. let
#     ml:f32[1] = max mj mi
#     mm:f32[1] = min mk ml
#   in (mm,) } in
# let _take20 = { lambda ; mn:f32[1,10] mo:i32[1]. let
#     mp:i32[1] = pjit[
#       name=remainder
#       jaxpr={ lambda ; z:i32[1] ba:i32[]. let
#           bb:bool[] = eq ba 0
#           bc:i32[] = pjit[
#             name=_where
#             jaxpr={ lambda ; g:bool[] h:i32[] i:i32[]. let
#                 j:i32[] = select_n g i h
#               in (j,) }
#           ] bb 1 ba
#           bd:i32[1] = rem z bc
#           be:bool[1] = ne bd 0
#           bf:bool[1] = lt bd 0
#           bg:bool[] = lt bc 0
#           bh:bool[1] = ne bf bg
#           bi:bool[1] = and bh be
#           bj:i32[1] = add bd bc
#           bk:i32[1] = select_n bi bd bj
#         in (bk,) }
#     ] mo 1
#     mq:i32[1,1] = broadcast_in_dim[
#       broadcast_dimensions=(0,)
#       shape=(1, 1)
#       sharding=None
#     ] mp
#     mr:f32[1,10] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(1,), collapsed_slice_dims=(0,), start_index_map=(0,), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=False
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1, 10)
#       unique_indices=False
#     ] mn mq
#   in (mr,) } in
# let _take21 = { lambda ; ms:f32[1] mt:i32[1]. let
#     mu:i32[1] = pjit[
#       name=remainder
#       jaxpr={ lambda ; z:i32[1] ba:i32[]. let
#           bb:bool[] = eq ba 0
#           bc:i32[] = pjit[
#             name=_where
#             jaxpr={ lambda ; g:bool[] h:i32[] i:i32[]. let
#                 j:i32[] = select_n g i h
#               in (j,) }
#           ] bb 1 ba
#           bd:i32[1] = rem z bc
#           be:bool[1] = ne bd 0
#           bf:bool[1] = lt bd 0
#           bg:bool[] = lt bc 0
#           bh:bool[1] = ne bf bg
#           bi:bool[1] = and bh be
#           bj:i32[1] = add bd bc
#           bk:i32[1] = select_n bi bd bj
#         in (bk,) }
#     ] mt 1
#     mv:i32[1,1] = broadcast_in_dim[
#       broadcast_dimensions=(0,)
#       shape=(1, 1)
#       sharding=None
#     ] mu
#     mw:f32[1] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(), collapsed_slice_dims=(0,), start_index_map=(0,), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=False
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1,)
#       unique_indices=False
#     ] ms mv
#   in (mw,) } in
# let _cho_solve = { lambda ; mx:f32[2,2] my:f32[2]. let
#     mz:f32[2,1] = broadcast_in_dim[
#       broadcast_dimensions=(0,)
#       shape=(2, 1)
#       sharding=None
#     ] my
#     na:f32[2,1] = triangular_solve[
#       conjugate_a=False
#       left_side=True
#       lower=False
#       transpose_a=True
#       unit_diagonal=False
#     ] mx mz
#     nb:f32[2,1] = slice[limit_indices=(2, 1) start_indices=(0, 0) strides=None] na
#     nc:f32[2] = squeeze[dimensions=(1,)] nb
#     nd:f32[2,1] = broadcast_in_dim[
#       broadcast_dimensions=(0,)
#       shape=(2, 1)
#       sharding=None
#     ] nc
#     ne:f32[2,1] = triangular_solve[
#       conjugate_a=False
#       left_side=True
#       lower=False
#       transpose_a=False
#       unit_diagonal=False
#     ] mx nd
#     nf:f32[2,1] = slice[limit_indices=(2, 1) start_indices=(0, 0) strides=None] ne
#     ng:f32[2] = squeeze[dimensions=(1,)] nf
#   in (ng,) } in
# let _where2 = { lambda ; nh:bool[] ni:f32[2] nj:f32[2]. let
#     nk:f32[2] = select_n nh nj ni
#   in (nk,) } in
# let remainder = { lambda ; c:i32[1,0] d:i32[]. let
#     e:bool[] = eq d 0
#     f:i32[] = pjit[
#       name=_where
#       jaxpr={ lambda ; g:bool[] h:i32[] i:i32[]. let
#           j:i32[] = select_n g i h
#         in (j,) }
#     ] e 1 d
#     k:i32[1,0] = rem c f
#     l:bool[1,0] = ne k 0
#     m:bool[1,0] = lt k 0
#     n:bool[] = lt f 0
#     o:bool[1,0] = ne m n
#     p:bool[1,0] = and o l
#     q:i32[1,0] = add k f
#     r:i32[1,0] = select_n p k q
#   in (r,) } in
# let remainder1 = { lambda ; z:i32[1] ba:i32[]. let
#     bb:bool[] = eq ba 0
#     bc:i32[] = pjit[
#       name=_where
#       jaxpr={ lambda ; g:bool[] h:i32[] i:i32[]. let
#           j:i32[] = select_n g i h
#         in (j,) }
#     ] bb 1 ba
#     bd:i32[1] = rem z bc
#     be:bool[1] = ne bd 0
#     bf:bool[1] = lt bd 0
#     bg:bool[] = lt bc 0
#     bh:bool[1] = ne bf bg
#     bi:bool[1] = and bh be
#     bj:i32[1] = add bd bc
#     bk:i32[1] = select_n bi bd bj
#   in (bk,) } in
# let remainder2 = { lambda ; ck:i32[1,1] cl:i32[]. let
#     cm:bool[] = eq cl 0
#     cn:i32[] = pjit[
#       name=_where
#       jaxpr={ lambda ; g:bool[] h:i32[] i:i32[]. let
#           j:i32[] = select_n g i h
#         in (j,) }
#     ] cm 1 cl
#     co:i32[1,1] = rem ck cn
#     cp:bool[1,1] = ne co 0
#     cq:bool[1,1] = lt co 0
#     cr:bool[] = lt cn 0
#     cs:bool[1,1] = ne cq cr
#     ct:bool[1,1] = and cs cp
#     cu:i32[1,1] = add co cn
#     cv:i32[1,1] = select_n ct co cu
#   in (cv,) } in
# let remainder3 = { lambda ; eu:i32[2] ev:i32[]. let
#     ew:bool[] = eq ev 0
#     ex:i32[] = pjit[
#       name=_where
#       jaxpr={ lambda ; g:bool[] h:i32[] i:i32[]. let
#           j:i32[] = select_n g i h
#         in (j,) }
#     ] ew 1 ev
#     ey:i32[2] = rem eu ex
#     ez:bool[2] = ne ey 0
#     fa:bool[2] = lt ey 0
#     fb:bool[] = lt ex 0
#     fc:bool[2] = ne fa fb
#     fd:bool[2] = and fc ez
#     fe:i32[2] = add ey ex
#     ff:i32[2] = select_n fd ey fe
#   in (ff,) } in
# let remainder4 = { lambda ; fq:i32[3] fr:i32[]. let
#     fs:bool[] = eq fr 0
#     ft:i32[] = pjit[
#       name=_where
#       jaxpr={ lambda ; g:bool[] h:i32[] i:i32[]. let
#           j:i32[] = select_n g i h
#         in (j,) }
#     ] fs 1 fr
#     fu:i32[3] = rem fq ft
#     fv:bool[3] = ne fu 0
#     fw:bool[3] = lt fu 0
#     fx:bool[] = lt ft 0
#     fy:bool[3] = ne fw fx
#     fz:bool[3] = and fy fv
#     ga:i32[3] = add fu ft
#     gb:i32[3] = select_n fz fu ga
#   in (gb,) } in
# let _where3 = { lambda ; iw:bool[2,2] ix:f32[2] iy:f32[2]. let
#     iz:f32[2,2] = broadcast_in_dim[
#       broadcast_dimensions=(1,)
#       shape=(2, 2)
#       sharding=None
#     ] ix
#     ja:f32[2,2] = broadcast_in_dim[
#       broadcast_dimensions=(1,)
#       shape=(2, 2)
#       sharding=None
#     ] iy
#     jb:f32[2,2] = select_n iw ja iz
#   in (jb,) } in
# let allclose = { lambda ; nl:f32[2] nm:f32[]. let
#     nn:bool[2] = pjit[
#       name=isclose
#       jaxpr={ lambda ; no:f32[2] np:f32[] nq:f32[] nr:f32[]. let
#           ns:f32[] = convert_element_type[new_dtype=float32 weak_type=False] np
#           nt:f32[] = convert_element_type[new_dtype=float32 weak_type=False] nq
#           nu:f32[] = convert_element_type[new_dtype=float32 weak_type=False] nr
#           nv:f32[2] = sub no ns
#           nw:f32[2] = abs nv
#           nx:f32[] = abs ns
#           ny:f32[] = mul nt nx
#           nz:f32[] = add nu ny
#           oa:bool[2] = le nw nz
#           ob:bool[2] = pjit[
#             name=isinf
#             jaxpr={ lambda ; oc:f32[2]. let
#                 od:f32[2] = abs oc
#                 oe:bool[2] = eq od inf
#               in (oe,) }
#           ] no
#           of:bool[] = pjit[
#             name=isinf
#             jaxpr={ lambda ; og:f32[]. let
#                 oh:f32[] = abs og
#                 oi:bool[] = eq oh inf
#               in (oi,) }
#           ] ns
#           oj:bool[2] = or ob of
#           ok:bool[2] = and ob of
#           ol:bool[2] = not oj
#           om:bool[2] = and oa ol
#           on:bool[2] = eq no ns
#           oo:bool[2] = and ok on
#           op:bool[2] = or om oo
#           oq:bool[2] = ne no no
#           or:bool[] = ne ns ns
#           os:bool[2] = or oq or
#           ot:bool[2] = not os
#           ou:bool[2] = and op ot
#         in (ou,) }
#     ] nl nm 1e-05 1e-08
#     ov:bool[] = reduce_and[axes=(0,)] nn
#   in (ov,) } in
# let norm = { lambda ; ow:f32[2]. let
#     ox:f32[2] = mul ow ow
#     oy:f32[] = reduce_sum[axes=(0,)] ox
#     oz:f32[] = sqrt oy
#   in (oz,) } in
# let _where4 = { lambda ; pa:bool[] pb:f32[] pc:f32[]. let
#     pd:f32[] = convert_element_type[new_dtype=float32 weak_type=False] pb
#     pe:f32[] = select_n pa pc pd
#   in (pe,) } in
# let _where5 = { lambda ; pf:bool[] pg:f32[] ph:f32[]. let
#     pi:f32[] = select_n pf ph pg
#   in (pi,) } in
# let _where6 = { lambda ; g:bool[] h:i32[] i:i32[]. let
#     j:i32[] = select_n g i h
#   in (j,) } in
# let _where7 = { lambda ; pj:bool[] pk:i32[] pl:i32[]. let
#     pm:i32[] = select_n pj pl pk
#   in (pm,) } in
# let isclose = { lambda ; no:f32[2] np:f32[] nq:f32[] nr:f32[]. let
#     ns:f32[] = convert_element_type[new_dtype=float32 weak_type=False] np
# ...
#                 gji:f32[2,2] = transpose[permutation=(1, 0)] frh
#                 gjj:f32[2] = dot_general[
#                   dimension_numbers=(([1], [0]), ([], []))
#                   preferred_element_type=float32
#                 ] gji gjb
#                 gjk:f32[2] = sub giq fri
#                 gjl:f32[2] = sub gim frk
#                 gjm:f32[] = dot_general[
#                   dimension_numbers=(([0], [0]), ([], []))
#                   preferred_element_type=float32
#                 ] gjk gjl
#                 gjn:f32[] = mul 0.5 gjm
#                 gjo:f32[] = add gjh gjn
#                 gjp:f32[] = add gjo 0.0
#                 gjq:f32[2] = sub giq fri
#                 gjr:f32[2] = sub gjq gjj
#                 gjs:f32[2,2] = transpose[permutation=(1, 0)] frh
#                 gjt:f32[1,2] = broadcast_in_dim[
#                   broadcast_dimensions=(1,)
#                   shape=(1, 2)
#                   sharding=None
#                 ] frj
#                 gju:f32[2,2] = mul gjs gjt
#                 gjv:f32[2] = convert_element_type[
#                   new_dtype=float32
#                   weak_type=False
#                 ] giv
#                 gjw:f32[1,2] = broadcast_in_dim[
#                   broadcast_dimensions=(1,)
#                   shape=(1, 2)
#                   sharding=None
#                 ] gjv
#                 gjx:f32[2,2] = mul gju gjw
#                 gjy:f32[2,2] = dot_general[
#                   dimension_numbers=(([1], [0]), ([], []))
#                   preferred_element_type=float32
#                 ] gjx frh
#                 gjz:f32[2,2] = add frg gjy
#                 gka:f32[2,2] = pjit[name=_cholesky jaxpr=_cholesky] gjz
#                 gkb:f32[2] = pjit[name=_cho_solve jaxpr=_cho_solve] gka gjr
#                 gkc:f32[2] = neg gkb
#                 gkd:i32[] = add frw 1
#               in (gim, gjj, giu, gjb, giq, gjr, gkb, gkc, gjn, gjp, fru, gkd, giv,
#                 fry, 0.0, 0.0, 0.0) }
#             body_nconsts=8
#             cond_jaxpr={ lambda ; gke:f32[] gkf:f32[] gkg:f32[2] gkh:f32[2] gki:f32[2]
#                 gkj:f32[2] gkk:f32[2] gkl:f32[2] gkm:f32[2] gkn:f32[2] gko:f32[]
#                 gkp:f32[] gkq:f32[] gkr:i32[] gks:bool[2] gkt:f32[] gku:f32[] gkv:f32[]
#                 gkw:f32[]. let
#                 gkx:f32[] = convert_element_type[
#                   new_dtype=float32
#                   weak_type=False
#                 ] gkq
#                 gky:f32[] = sub gkx gkp
#                 gkz:f32[] = mul gke 2.0
#                 gla:f32[] = div gky gkz
#                 glb:bool[] = pjit[name=allclose jaxpr=allclose] gkl 0.0
#                 glc:f32[2] = broadcast_in_dim[
#                   broadcast_dimensions=()
#                   shape=(2,)
#                   sharding=None
#                 ] 1.0
#                 gld:f32[2] = pjit[name=_where jaxpr=_where2] glb glc gkl
#                 gle:f32[] = pjit[name=norm jaxpr=norm] gld
#                 glf:f32[] = pjit[name=_where jaxpr=_where4] glb 0.0 gle
#                 glg:f32[] = mul gke 2.0
#                 glh:f32[] = div glf glg
#                 gli:bool[] = ge gkr 100
#                 glj:bool[] = lt gla gkf
#                 glk:bool[] = convert_element_type[
#                   new_dtype=bool
#                   weak_type=False
#                 ] gli
#                 gll:bool[] = or glk glj
#                 glm:bool[] = lt glh gkf
#                 gln:bool[] = or gll glm
#                 glo:bool[] = not gln
#               in (glo,) }
#             cond_nconsts=2
#           ] bmd bme bmd bme bmf ene epn fnr esy fns fpo fqg fpq fpy fpr fqo fqy fqz
#             fqk fqm inf 0 fps 0.0 0.0 0.0 0.0
#           glp:f32[2] = mul bjf bkm
#           glq:f32[2,2] = pjit[name=_diag jaxpr=_diag] glp
#           glr:f32[2,2] = add ene glq
#           gls:f32[2,2] = pjit[name=_cholesky jaxpr=_cholesky] glr
#           glt:f32[2] = add fnr frb
#           glu:f32[2] = pjit[name=_cho_solve jaxpr=_cho_solve] gls glt
#           glv:f32[2] = mul glu bjf
#           glw:f32[2] = add bmr glv
#           glx:f32[1,1] = pjit[name=_take jaxpr=_take8] cys bmg
#           gly:f32[1,1] = pjit[name=_take jaxpr=_take8] glw bmh
#           glz:f32[1,1] = slice[
#             limit_indices=(1, 1)
#             start_indices=(0, 0)
#             strides=None
#           ] glx
#           gma:f32[1] = squeeze[dimensions=(1,)] glz
#           gmb:f32[1,1] = slice[
#             limit_indices=(1, 1)
#             start_indices=(0, 0)
#             strides=None
#           ] gly
#           gmc:f32[1] = squeeze[dimensions=(1,)] gmb
#           gmd:f32[1] = mul bjf gmc
#           gme:f32[1] = add gma gmd
#           gmf:f32[1,1] = broadcast_in_dim[
#             broadcast_dimensions=(0,)
#             shape=(1, 1)
#             sharding=None
#           ] gme
#           gmg:f32[1,1] = pjit[name=_take jaxpr=_take8] cys bmi
#           gmh:f32[1,1] = pjit[name=_take jaxpr=_take8] glw bmj
#           gmi:f32[1,1] = slice[
#             limit_indices=(1, 1)
#             start_indices=(0, 0)
#             strides=None
#           ] gmg
#           gmj:f32[1] = squeeze[dimensions=(1,)] gmi
#           gmk:f32[1,1] = slice[
#             limit_indices=(1, 1)
#             start_indices=(0, 0)
#             strides=None
#           ] gmh
#           gml:f32[1] = squeeze[dimensions=(1,)] gmk
#           gmm:f32[1] = mul bjf gml
#           gmn:f32[1] = add gmj gmm
#           gmo:f32[1,1] = broadcast_in_dim[
#             broadcast_dimensions=(0,)
#             shape=(1, 1)
#             sharding=None
#           ] gmn
#           gmp:f32[1] = reshape[dimensions=None new_sizes=(1,) sharding=None] gmf
#           gmq:f32[1] = reshape[dimensions=None new_sizes=(1,) sharding=None] gmo
#           gmr:f32[2] = concatenate[dimension=0] gmp gmq
#           gms:f32[2] = pjit[name=_take jaxpr=_take11] gmr bmk
#           gmt:f32[] = add bmp bjf
#           gmu:f32[2,3] = slice[
#             limit_indices=(3, 3)
#             start_indices=(1, 0)
#             strides=None
#           ] cze
#           gmv:f32[2,4] = slice[
#             limit_indices=(3, 4)
#             start_indices=(1, 0)
#             strides=None
#           ] czg
#           gmw:f32[2,3] = slice[
#             limit_indices=(3, 6)
#             start_indices=(1, 3)
#             strides=None
#           ] fad
#           gmx:f32[2,3] = slice[
#             limit_indices=(3, 3)
#             start_indices=(1, 0)
#             strides=None
#           ] fad
#           gmy:f32[2,3] = slice[
#             limit_indices=(3, 3)
#             start_indices=(1, 0)
#             strides=None
#           ] cze
#           gmz:i32[2] = device_put[
#             copy_semantics=[<CopySemantics.ALIAS: 1>]
#             devices=[None]
#             srcs=[None]
#           ] bml
#           gna:bool[2] = lt gmz 0
#           gnb:i32[2] = add gmz 3
#           gnc:i32[2] = select_n gna gmz gnb
#           gnd:i32[2,1] = broadcast_in_dim[
#             broadcast_dimensions=(0,)
#             shape=(2, 1)
#             sharding=None
#           ] gnc
#           gne:f32[2,3] = gather[
#             dimension_numbers=GatherDimensionNumbers(offset_dims=(1,), collapsed_slice_dims=(0,), start_index_map=(0,), operand_batching_dims=(), start_indices_batching_dims=())
#             fill_value=None
#             indices_are_sorted=False
#             mode=GatherScatterMode.PROMISE_IN_BOUNDS
#             slice_sizes=(1, 3)
#             unique_indices=False
#           ] drz gnd
#           gnf:f32[2,3] = sub gmy gne
#           gng:f32[1,1,1,4] = reshape[
#             dimensions=None
#             new_sizes=(1, 1, 1, 4)
#             sharding=None
#           ] bmm
#           gnh:f32[2,1,1,4] = broadcast_in_dim[
#             broadcast_dimensions=(0, 1, 2, 3)
#             shape=(2, 1, 1, 4)
#             sharding=None
#           ] gng
#           gni:f32[2,4] = reshape[dimensions=None new_sizes=(2, 4) sharding=None] gnh
#           gnj:f32[4] = convert_element_type[new_dtype=float32 weak_type=False] bmn
#           gnk:f32[1,4] = broadcast_in_dim[
#             broadcast_dimensions=(np.int64(1),)
#             shape=(1, 4)
#             sharding=None
#           ] gnj
#           gnl:f32[2,4] = mul gni gnk
#           gnm:f32[2,1] = slice[
#             limit_indices=(2, 1)
#             start_indices=(0, 0)
#             strides=None
#           ] gnl
#           gnn:f32[2] = squeeze[dimensions=(1,)] gnm
#           gno:f32[2,3] = slice[
#             limit_indices=(2, 4)
#             start_indices=(0, 1)
#             strides=None
#           ] gnl
#           gnp:f32[2] = dot_general[
#             dimension_numbers=(([1], [1]), ([0], [0]))
#             preferred_element_type=float32
#           ] gno gmx
#           gnq:f32[2,1] = broadcast_in_dim[
#             broadcast_dimensions=(0,)
#             shape=(2, 1)
#             sharding=None
#           ] gnp
#           gnr:f32[2,3] = mul gnq gno
#           gns:f32[2,3] = mul 2.0 gnr
#           gnt:f32[2] = mul gnn gnn
#           gnu:f32[2] = dot_general[
#             dimension_numbers=(([1], [1]), ([0], [0]))
#             preferred_element_type=float32
#           ] gno gno
#           gnv:f32[2] = sub gnt gnu
#           gnw:f32[2,1] = broadcast_in_dim[
#             broadcast_dimensions=(0,)
#             shape=(2, 1)
#             sharding=None
#           ] gnv
#           gnx:f32[2,3] = mul gnw gmx
#           gny:f32[2,3] = add gns gnx
#           gnz:f32[2] = mul 2.0 gnn
#           goa:f32[2,3] = pjit[name=cross jaxpr=cross2] gno gmx
#           gob:f32[2,1] = broadcast_in_dim[
#             broadcast_dimensions=(0,)
#             shape=(2, 1)
#             sharding=None
#           ] gnz
#           goc:f32[2,3] = mul gob goa
#           god:f32[2,3] = add gny goc
#           goe:f32[2,3] = pjit[name=cross jaxpr=cross2] gnf gmx
#           gof:f32[2,3] = sub gmw goe
#           gog:f32[2,1] = slice[
#             limit_indices=(2, 1)
#             start_indices=(0, 0)
#             strides=None
#           ] gnl
#           goh:f32[2] = squeeze[dimensions=(1,)] gog
#           goi:f32[2,3] = slice[
#             limit_indices=(2, 4)
#             start_indices=(0, 1)
#             strides=None
#           ] gnl
#           goj:f32[2] = dot_general[
#             dimension_numbers=(([1], [1]), ([0], [0]))
#             preferred_element_type=float32
#           ] goi gof
#           gok:f32[2,1] = broadcast_in_dim[
#             broadcast_dimensions=(0,)
#             shape=(2, 1)
#             sharding=None
#           ] goj
#           gol:f32[2,3] = mul gok goi
#           gom:f32[2,3] = mul 2.0 gol
#           gon:f32[2] = mul goh goh
#           goo:f32[2] = dot_general[
#             dimension_numbers=(([1], [1]), ([0], [0]))
#             preferred_element_type=float32
#           ] goi goi
#           gop:f32[2] = sub gon goo
#           goq:f32[2,1] = broadcast_in_dim[
#             broadcast_dimensions=(0,)
#             shape=(2, 1)
#             sharding=None
#           ] gop
#           gor:f32[2,3] = mul goq gof
#           gos:f32[2,3] = add gom gor
#           got:f32[2] = mul 2.0 goh
#           gou:f32[2,3] = pjit[name=cross jaxpr=cross2] goi gof
#           gov:f32[2,1] = broadcast_in_dim[
#             broadcast_dimensions=(0,)
#             shape=(2, 1)
#             sharding=None
#           ] got
#           gow:f32[2,3] = mul gov gou
#           gox:f32[2,3] = add gos gow
#         in (bmo, gmt, gms, glw, bms, fra, blj, bmv, bmw, bmx, bmy, bmz, fra, fgm,
#           bnc, bnd, cze, czg, czn, dal, dho, cyx, czc, dit, dpw, bnn, bno, ejt, eju,
#           bnr, bns, drz, ejs, eis, bnw, bnx, bny, bnz, boa, bob, boc, bod, boe, bof,
#           bog, boh, boi, boj, bok, bol, exy, bon, boo, bop, exx, ekw, ene, enf, bou,
#           bov, bow, box, eya, exz, fad, fai, fgf, bpd, bpe, fcf, bpg, fce, bpi, bpj,
#           bpk, bpl, bpm, bpn, bpo, bpp, bpq, bpr, bps, bpt, bpu, bpv, bpw, bpx, bpy,
#           bpz, bqa, fhu, fgz, fnr, fns, frb, bqg, bqh, bqi, bqj, bqk, bql, bqm, bqn,
#           bqo, bqp, bqq, bqr, bqs, bqt, bqu, bqv, bqw, bqx, bqy, epn, esx, enr, epq,
#           esy, esw, frc, brg, brh, bri, gms, glw, gmu, gmv, god, gox) }
#       length=2
#       linear=(False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False)
#       num_carry=131
#       num_consts=162
#       reverse=False
#       unroll=1
#     ] po pp pq pr ps pt pu pv pw px py pz qa qb qc qd qe qf qg qh qi qj qk ql qm
#       qn qo qp qq qr qs qt qu qv qw qx qy qz ra rb rc rd re rf rg rh ri rj rk rl
#       rm rn ro rp rq rr rs rt ru rv rw rx ry rz sa sb sc sd se sf sg sh si sj sk
#       sl sm sn so sp sq sr ss st su sv sw sx sy sz ta tb tc td te tf tg th ti tj
#       tk tl tm tn to tp tq tr ts tt tu tv tw tx ty tz ua ub uc ud ue uf ug uh ui
#       uj uk ul um un uo bbg up uq ur us ut uu uv uw ux uy uz va vb vc vd ve vf vg
#       vh vi vj vk vl vm vn vo vp vq vr vs vt vu vv vw vx vy vz wa wb wc wd we wf
#       wg wh wi wj wk wl wm wn wo wp wq wr ws wt wu wv ww wx wy wz xa xb xc xd xe
#       xf xg xh xi xj xk xl xm xn xo xp xq xr xs xt xu xv xw xx xy xz ya yb yc yd
#       ye yf yg yh yi yj yk yl ym yn yo yp yq yr ys yt yu yv yw yx yy yz za zb zc
#       zd ze zf zg zh zi zj zk zl zm zn zo zp zq zr zs zt zu zv zw zx zy zz baa bab
#       bac bad bae baf bag bah bai baj bak bal bam ban bao bap baq bar bas bat
#     goy:f32[4] = concatenate[dimension=0] bgc bgd
#     goz:f32[1] = slice[limit_indices=(2,) start_indices=(1,) strides=None] goy
#     gpa:f32[] = squeeze[dimensions=(0,)] goz
#     gpb:f32[] = abs gpa
#     gpc:bool[] = gt gpb 0.20000000298023224
#     gpd:f32[] = pjit[
#       name=_where
#       jaxpr={ lambda ; gpe:bool[] gpf:f32[] gpg:f32[]. let
#           gph:f32[] = select_n gpe gpg gpf
#         in (gph,) }
#     ] gpc 1.0 0.0
#   in (bbh, bbi, bbj, bbk, bbl, bbm, bbn, bbo, bbp, bbq, bbr, bbs, bbt, bbu, bbv,
#     bbw, bbx, bby, bbz, bca, bcb, bcc, bcd, bce, bcf, bcg, bch, bci, bcj, bck, bcl,
#     bcm, bcn, bco, bcp, bcq, bcr, bcs, bct, bcu, bcv, bcw, bcx, bcy, bcz, bda, bdb,
#     bdc, bdd, bde, bdf, bdg, bdh, bdi, bdj, bdk, bdl, bdm, bdn, bdo, bdp, bdq, bdr,
#     bds, bdt, bdu, bdv, bdw, bdx, bdy, bdz, bea, beb, bec, bed, bee, bef, beg, beh,
#     bei, bej, bek, bel, bem, ben, beo, bep, beq, ber, bes, bet, beu, bev, bew, bex,
#     bey, bez, bfa, bfb, bfc, bfd, bfe, bff, bfg, bfh, bfi, bfj, bfk, bfl, bfm, bfn,
#     bfo, bfp, bfq, bfr, bfs, bft, bfu, bfv, bfw, bfx, bfy, bfz, bga, bgb, bgc, bgd,
#     bge, bgf, bgg, bgh, goy, 1.0, gpd) }

# %%
jax.jit(env.step).lower(state, actions).compile().cost_analysis()["flops"]
# Out:
# 5304.0

# %%
jitted = jax.jit(env.step).lower(state, actions).compile().cost_analysis()
sum_cost_utilization(jitted)
# Out:
# 6137.479248046875
